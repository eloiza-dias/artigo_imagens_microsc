# %% [markdown]
# <a href="https://colab.research.google.com/github/eloiza-dias/artigo_imagens_microsc/blob/main/5_Redes_neurais_a549_maior_erro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linhagem A549

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Importações estruturação dos dados

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %%
pip install util-gfsilveira
# Out:
# Collecting util-gfsilveira
#   Downloading util_gfsilveira-0.1-py3-none-any.whl (3.1 kB)
# Installing collected packages: util-gfsilveira
# Successfully installed util-gfsilveira-0.1

# %% [markdown]
# # Importação do modelo de CNN

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Os documentos de diferentes arquivos serão armazenados nesse diretório

# %%
diretorio = '/content/drive/MyDrive/1_Informações_scripts' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_regressao_3T3_samehuh72021-10-25.gz
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_3T3_samehuh72021-10-25.gz
# 2 -> lista_img_camp_clar_100_resized_regressao_A549_samehuh72021-10-25.gz
# 3 -> lista_rotulo_camp_clar_100_resized_regressao_A549_samehuh72021-10-25.gz
# 4 -> lista_img_camp_clar_100_resized_regressao_huh7_samehuh72021-10-25.gz
# 5 -> lista_rotulo_camp_clar_100_resized_regressao_huh7_samehuh72021-10-25.gz
# 6 -> model_A549_samehuh7_img2021-10-26.h5
# 7 -> model_huh7_samehuh7_img2021-10-26.h5
# 8 -> model__3T3_samehuh7_img2021-10-26.h5
# 9 -> model_A549_samehuh7_img_40_602021-10-27.h5
# 10 -> model_huh7_samehuh7_img_40_602021-10-27.h5
# 11 -> model__3T3_samehuh7_img_40_602021-10-27.h5
# 12 -> lista_img_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 13 -> lista_rotulo_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 14 -> lista_img_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 15 -> lista_rotulo_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 16 -> lista_img_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 17 -> lista_rotulo_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 18 -> lista_img_camp_clar_25_resized_regressao_A5492021-11-9.gz
# 19 -> lista_rotulo_camp_clar_25_resized_regressao_A5492021-11-9.gz
# 20 -> lista_img_camp_clar_100_resized_regressao_huh72021-11-9.gz
# 21 -> lista_rotulo_camp_clar_100_resized_regressao_huh72021-11-9.gz
# 22 -> lista_img_camp_clar_75_resized_regressao_HUH72021-11-9.gz
# 23 -> lista_rotulo_camp_clar_75_resized_regressao_HUH72021-11-9.gz
# 24 -> lista_img_camp_clar_50_resized_regressao_HUH72021-11-9.gz
# 25 -> lista_rotulo_camp_clar_50_resized_regressao_HUH72021-11-9.gz
# 26 -> lista_rotulo_camp_clar_25_resized_regressao_HUH72021-11-9.gz
# 27 -> lista_img_camp_clar_25_resized_regressao_HUH72021-11-9.gz
# 28 -> lista_img_camp_clar_100_resized_regressao_3T32021-11-9.gz
# 29 -> lista_rotulo_camp_clar_100_resized_regressao_3T32021-11-9.gz
# 30 -> lista_img_camp_clar_75_resized_regressao_3T3_2021-11-9.gz
# 31 -> lista_rotulo_camp_clar_75_resized_regressao_3T3_2021-11-9.gz
# 32 -> lista_img_camp_clar_50_resized_regressao_3T3_2021-11-9.gz
# 33 -> lista_rotulo_camp_clar_50_resized_regressao_3T3_2021-11-9.gz
# 34 -> lista_img_camp_clar_25_resized_regressao_3T3_2021-11-9.gz
# 35 -> lista_rotulo_camp_clar_25_resized_regressao_3T3_2021-11-9.gz
# 36 -> model_A549_100_75_50_25_2021-11-11.h5
# 37 -> model_HUH7_100_75_50_25_2021-11-11.h5
# 38 -> model_3T3_100_75_50_25_2021-11-11.h5
# 39 -> images_de_x_caracteristicas_a549.gz
# 40 -> images_de_y_caracteristicas_a549.gz
# 41 -> images_de_x_caracteristicas_Huh7.gz
# 42 -> rotulos_de_y_caracteristicas_Huh7.gz
# 43 -> images_de_x_caracteristicas_3T3.gz
# 44 -> rotulos_de_y_caracteristicas_3T3.gz

# %% [markdown]
# Para regressão, foi salvo 284 imagens a partir de 71 imagens originais

# %%
#lista- soma de 284 imagens
imagem_camp_claro = joblib.load(diretorio+ '/' + lista_dados[2])
imagem_camp_claro.shape #apresentando 4000 imagens de 108x108, 3 rgb
# Out:
# (176, 200, 200, 3)

# %% [markdown]
# ## x = características/imagens

# %%
#somando cada lista gerada acima e salvando em um array
x = np.asarray(imagem_camp_claro) #abriando em array as imagens
x.shape #x - características (labels)
# Out:
# (176, 200, 200, 3)

# %%
#joblib.dump(x, 'arquivos_text_modelo_imagens//images_de_x_caracteristicas.gz')

# %% [markdown]
# Vamos definir nossos rótulos (y)

# %% [markdown]
# ## y = rótulos

# %% [markdown]
# Abrindo os rótulos que foram salvos na preparação das imagens

# %%
y_rotulo = joblib.load(diretorio+ '/' + lista_dados[3]) #carregando os rotulos
y = np.asarray(y_rotulo)
y.shape
# Out:
# (176,)

# %%
#y.max()
#y.min()
# Out:
# 1267

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# Separação de teste e treino a partir de uma biblioteca.

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (123, 200, 200, 3)
# (53, 200, 200, 3)
# (123,)
# (53,)

# %%
joblib.dump(X_train, '/content/drive/MyDrive/1_Informações_scripts//1_images_de_X_train_a549_pior_modelo.gz')
# Out:
# ['/content/drive/MyDrive/1_Informações_scripts//1_images_de_X_train_a549_pior_modelo.gz']

# %%
joblib.dump(y_train, '/content/drive/MyDrive/1_Informações_scripts//1_images_de_y_train_a549_pior_modelo.gz')
# Out:
# ['/content/drive/MyDrive/1_Informações_scripts//1_images_de_y_train_a549_pior_modelo.gz']

# %%
joblib.dump(X_test, '/content/drive/MyDrive/1_Informações_scripts//2_images_de_X_test_a549_pior_modelo.gz')
# Out:
# ['/content/drive/MyDrive/1_Informações_scripts//2_images_de_X_test_a549_pior_modelo.gz']

# %%
joblib.dump(y_test, '/content/drive/MyDrive/1_Informações_scripts//2_images_de_y_test_a549_pior_modelo.gz')
# Out:
# ['/content/drive/MyDrive/1_Informações_scripts//2_images_de_y_test_a549_pior_modelo.gz']

# %% [markdown]
# Para treinar o modelo, geralmente é selecionada 30% das imagens para o treino e 70% para teste. Para isso, as imagens são guardadas em uma variável de teste (somente 30%) e o restante vai para o treino.

# %% [markdown]
# ### Determinação do modelo

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_absolute_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Após correr o modelo de Redes Neurais, vamos treina-lo em algumas rodadas e verificar a acurácia.

# %% [markdown]
# Guardando&nbsp;em&nbsp;uma&nbsp;variável&nbsp;o&nbsp;treinamento&nbsp;do&nbsp;modelo&nbsp;-&nbsp;informando&nbsp;as&nbsp;imagens&nbsp;com&nbsp;as&nbsp;caracteristicas (X_treino) e junto a elas os rótulos, validando com os valores de teste em 10 rodadas

# %%
#rodadas de treinamento
history = modelo.fit(
                        X_train,
                        y_train,
                        validation_data=(X_test, y_test),
                        epochs=50,
                        batch_size=12
                    )
# Out:
# Epoch 1/50
# 11/11 [==============================] - 9s 787ms/step - loss: 271424.7188 - mean_absolute_error: 428.7501 - val_loss: 88238.8750 - val_mean_absolute_error: 239.6564
# Epoch 2/50
# 11/11 [==============================] - 8s 772ms/step - loss: 62271.7422 - mean_absolute_error: 198.1951 - val_loss: 61382.3008 - val_mean_absolute_error: 201.2721
# Epoch 3/50
# 11/11 [==============================] - 11s 1s/step - loss: 56532.1758 - mean_absolute_error: 190.6270 - val_loss: 32532.1270 - val_mean_absolute_error: 151.5354
# Epoch 4/50
# 11/11 [==============================] - 9s 766ms/step - loss: 32521.6035 - mean_absolute_error: 149.2687 - val_loss: 93221.3281 - val_mean_absolute_error: 265.4736
# Epoch 5/50
# 11/11 [==============================] - 11s 1000ms/step - loss: 43871.9336 - mean_absolute_error: 176.5326 - val_loss: 31590.8301 - val_mean_absolute_error: 148.2895
# Epoch 6/50
# 11/11 [==============================] - 10s 931ms/step - loss: 34517.7305 - mean_absolute_error: 153.0708 - val_loss: 31120.2539 - val_mean_absolute_error: 146.2803
# Epoch 7/50
# 11/11 [==============================] - 8s 760ms/step - loss: 34243.1914 - mean_absolute_error: 148.1224 - val_loss: 30146.2305 - val_mean_absolute_error: 141.4904
# Epoch 8/50
# 11/11 [==============================] - 8s 762ms/step - loss: 36021.4023 - mean_absolute_error: 149.3966 - val_loss: 30315.5566 - val_mean_absolute_error: 139.2226
# Epoch 9/50
# 11/11 [==============================] - 8s 763ms/step - loss: 35664.2773 - mean_absolute_error: 149.4305 - val_loss: 30188.5156 - val_mean_absolute_error: 142.3332
# Epoch 10/50
# 11/11 [==============================] - 8s 755ms/step - loss: 32343.7559 - mean_absolute_error: 142.5375 - val_loss: 34785.6172 - val_mean_absolute_error: 159.0287
# Epoch 11/50
# 11/11 [==============================] - 8s 762ms/step - loss: 36545.1758 - mean_absolute_error: 153.8739 - val_loss: 34889.8750 - val_mean_absolute_error: 159.3162
# Epoch 12/50
# 11/11 [==============================] - 8s 754ms/step - loss: 30194.6133 - mean_absolute_error: 143.1702 - val_loss: 33152.4219 - val_mean_absolute_error: 154.6633
# Epoch 13/50
# 11/11 [==============================] - 8s 760ms/step - loss: 34947.9883 - mean_absolute_error: 153.1079 - val_loss: 38311.8320 - val_mean_absolute_error: 166.7531
# Epoch 14/50
# 11/11 [==============================] - 8s 762ms/step - loss: 35336.5000 - mean_absolute_error: 151.6051 - val_loss: 36883.9258 - val_mean_absolute_error: 163.8530
# Epoch 15/50
# 11/11 [==============================] - 8s 758ms/step - loss: 37662.3086 - mean_absolute_error: 158.0338 - val_loss: 41540.1602 - val_mean_absolute_error: 173.4583
# Epoch 16/50
# 11/11 [==============================] - 8s 755ms/step - loss: 33840.7188 - mean_absolute_error: 146.7700 - val_loss: 30110.2070 - val_mean_absolute_error: 142.9880
# Epoch 17/50
# 11/11 [==============================] - 8s 754ms/step - loss: 32648.9297 - mean_absolute_error: 144.2243 - val_loss: 29485.2969 - val_mean_absolute_error: 137.5393
# Epoch 18/50
# 11/11 [==============================] - 8s 749ms/step - loss: 36317.6797 - mean_absolute_error: 155.8814 - val_loss: 39581.9531 - val_mean_absolute_error: 169.2713
# Epoch 19/50
# 11/11 [==============================] - 8s 754ms/step - loss: 31962.4297 - mean_absolute_error: 139.9045 - val_loss: 29258.1953 - val_mean_absolute_error: 139.6039
# Epoch 20/50
# 11/11 [==============================] - 8s 756ms/step - loss: 35695.4062 - mean_absolute_error: 150.2511 - val_loss: 29521.2695 - val_mean_absolute_error: 138.2551
# Epoch 21/50
# 11/11 [==============================] - 8s 755ms/step - loss: 39975.0117 - mean_absolute_error: 163.3855 - val_loss: 39677.9531 - val_mean_absolute_error: 170.2723
# Epoch 22/50
# 11/11 [==============================] - 8s 752ms/step - loss: 31874.8887 - mean_absolute_error: 146.9644 - val_loss: 32275.5449 - val_mean_absolute_error: 145.5858
# Epoch 23/50
# 11/11 [==============================] - 8s 759ms/step - loss: 36405.0469 - mean_absolute_error: 152.5996 - val_loss: 29050.5820 - val_mean_absolute_error: 138.0940
# Epoch 24/50
# 11/11 [==============================] - 8s 757ms/step - loss: 32810.3203 - mean_absolute_error: 143.3589 - val_loss: 28517.8770 - val_mean_absolute_error: 135.3680
# Epoch 25/50
# 11/11 [==============================] - 8s 753ms/step - loss: 32151.3359 - mean_absolute_error: 142.3270 - val_loss: 33033.1094 - val_mean_absolute_error: 155.1050
# Epoch 26/50
# 11/11 [==============================] - 8s 757ms/step - loss: 34331.1328 - mean_absolute_error: 150.9985 - val_loss: 43002.6523 - val_mean_absolute_error: 176.9343
# Epoch 27/50
# 11/11 [==============================] - 8s 760ms/step - loss: 37804.0430 - mean_absolute_error: 153.1872 - val_loss: 32317.4863 - val_mean_absolute_error: 146.2054
# Epoch 28/50
# 11/11 [==============================] - 8s 762ms/step - loss: 36737.4531 - mean_absolute_error: 160.5898 - val_loss: 29217.1094 - val_mean_absolute_error: 137.5852
# Epoch 29/50
# 11/11 [==============================] - 8s 762ms/step - loss: 30310.0664 - mean_absolute_error: 139.1196 - val_loss: 30312.5566 - val_mean_absolute_error: 145.5364
# Epoch 30/50
# 11/11 [==============================] - 8s 763ms/step - loss: 30932.8086 - mean_absolute_error: 143.8427 - val_loss: 35711.1328 - val_mean_absolute_error: 161.3196
# Epoch 31/50
# 11/11 [==============================] - 8s 753ms/step - loss: 28472.0352 - mean_absolute_error: 141.4034 - val_loss: 29027.4336 - val_mean_absolute_error: 138.0987
# Epoch 32/50
# 11/11 [==============================] - 8s 752ms/step - loss: 39302.9258 - mean_absolute_error: 160.4003 - val_loss: 37295.8281 - val_mean_absolute_error: 164.6620
# Epoch 33/50
# 11/11 [==============================] - 8s 755ms/step - loss: 42217.3164 - mean_absolute_error: 168.8507 - val_loss: 28041.6738 - val_mean_absolute_error: 134.5873
# Epoch 34/50
# 11/11 [==============================] - 8s 754ms/step - loss: 29892.7930 - mean_absolute_error: 142.0712 - val_loss: 35232.1758 - val_mean_absolute_error: 160.1202
# Epoch 35/50
# 11/11 [==============================] - 8s 762ms/step - loss: 32027.7500 - mean_absolute_error: 143.5378 - val_loss: 28838.6836 - val_mean_absolute_error: 138.0503
# Epoch 36/50
# 11/11 [==============================] - 8s 763ms/step - loss: 32896.3594 - mean_absolute_error: 147.9234 - val_loss: 29422.3066 - val_mean_absolute_error: 144.1565
# Epoch 37/50
# 11/11 [==============================] - 8s 762ms/step - loss: 30185.7422 - mean_absolute_error: 140.7783 - val_loss: 48907.4609 - val_mean_absolute_error: 187.5720
# Epoch 38/50
# 11/11 [==============================] - 8s 758ms/step - loss: 36038.5039 - mean_absolute_error: 151.1064 - val_loss: 40152.7344 - val_mean_absolute_error: 170.4462
# Epoch 39/50
# 11/11 [==============================] - 8s 752ms/step - loss: 29987.5801 - mean_absolute_error: 137.1842 - val_loss: 30138.9668 - val_mean_absolute_error: 147.0129
# Epoch 40/50
# 11/11 [==============================] - 8s 763ms/step - loss: 23841.6973 - mean_absolute_error: 127.3210 - val_loss: 34880.3477 - val_mean_absolute_error: 153.7649
# Epoch 41/50
# 11/11 [==============================] - 8s 760ms/step - loss: 37932.8984 - mean_absolute_error: 158.6391 - val_loss: 34577.6367 - val_mean_absolute_error: 158.7953
# Epoch 42/50
# 11/11 [==============================] - 8s 753ms/step - loss: 40150.9141 - mean_absolute_error: 157.6131 - val_loss: 56228.3242 - val_mean_absolute_error: 200.7952
# Epoch 43/50
# 11/11 [==============================] - 8s 751ms/step - loss: 34603.0625 - mean_absolute_error: 142.4143 - val_loss: 30890.1504 - val_mean_absolute_error: 148.3244
# Epoch 44/50
# 11/11 [==============================] - 8s 761ms/step - loss: 27807.9160 - mean_absolute_error: 132.6370 - val_loss: 49918.5625 - val_mean_absolute_error: 189.7213
# Epoch 45/50
# 11/11 [==============================] - 8s 764ms/step - loss: 38115.7422 - mean_absolute_error: 158.2411 - val_loss: 29417.0371 - val_mean_absolute_error: 143.6257
# Epoch 46/50
# 11/11 [==============================] - 8s 754ms/step - loss: 34073.3359 - mean_absolute_error: 148.6534 - val_loss: 33286.2812 - val_mean_absolute_error: 150.2807
# Epoch 47/50
# 11/11 [==============================] - 8s 753ms/step - loss: 29059.6680 - mean_absolute_error: 136.1813 - val_loss: 28871.8594 - val_mean_absolute_error: 138.3882
# Epoch 48/50
# 11/11 [==============================] - 8s 754ms/step - loss: 25820.9551 - mean_absolute_error: 132.4650 - val_loss: 37033.5039 - val_mean_absolute_error: 164.0454
# Epoch 49/50
# 11/11 [==============================] - 8s 756ms/step - loss: 29450.3926 - mean_absolute_error: 140.7529 - val_loss: 35058.8906 - val_mean_absolute_error: 159.3130
# Epoch 50/50
# 11/11 [==============================] - 8s 751ms/step - loss: 32373.1035 - mean_absolute_error: 146.4017 - val_loss: 28884.0566 - val_mean_absolute_error: 138.0696

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__A549_regressao_maior_erro'+data+'.h5')

# %% [markdown]
# ## Avaliação da Acurácia

# %% [markdown]
# Existem algumas maneiras de se avaliar a acurácia dos algoritmos, para algoritmo de regressão, as métricas mais comuns são Erro médio absoluto (MSE) não se baseia na média a partir de valores discrepantes. Erro Médio quadrático (MAE) considera os valores discrepantes entre as variáveis, apontando maior erro.

# %% [markdown]
# O algoritmo avalia o valor previsto e subtraí pelo valor conhecido, depois é calculado a média entre cada valor.

# %%
# #salvando o modelo
# data = timeProcess()[1]
# modelo.save('arquivos_text_modelo_imagens//model_camp_claro_A549_regressao'+data+'.h5')

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.plot(prev)
plt.plot(y_test)
plt.show()

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}% r2_score") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)} Erro médio absoluto") 
print(f"{round(mean_squared_log_error(y_test, prev), 2)} Erro médio quadrático") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
# Out:
# -209.95% r2_score
# 193.86 Erro médio absoluto
# 0.06 Erro médio quadrático

# %%
mean_absolute_error(y_test, prev)
# Out:
# 193.85687255859375

# %%
print(f"{round(mean_absolute_error(y_test, prev), 2)}") #erro médio absoluto
# Out:
# 193.86

# %%
print(f"{round(mean_squared_log_error(y_test, prev), 2)}") #erro médio quadrático
# Out:
# 0.06

# %%
# # #salvando o modelo
# data = timeProcess()[1]
# modelo.save('arquivos_text_modelo_imagens//model_camp_claro_A549_regressao_2_modelo'+data+'.h5')

# %% [markdown]
# ## Predição Regressão

# %%
from PIL import Image

# %%
#chamando o diretório com as imagens
previsao_imagens = "imagens_campo_claro_A549/"
lista_cell = os.listdir(previsao_imagens)
#lista_cell #lista das imagens

# %%
img_key = 54 #qual a chave a imagem
resize_img = (200,200) #tamanho
image_test = previsao_imagens + '/' + lista_cell[img_key] #da onde essa imagem está vindo

y_classes_base = [n.split('rot')[1] for n in lista_cell] #cortando o nome da image
y_classes_base = [int(n.split('_')[0]) for n in y_classes_base]

#trabalhando com as dimensões e mudando para numpy
img = Image.open(image_test)
img = img.resize(resize_img)
img = np.asarray(img)[:,:,:3]
img_to_prd = np.expand_dims(img, axis=0)


#gerando o gráfico
pred_img = modelo.predict(img_to_prd)[0]
pred_img = round(float(pred_img), 2)
med_img = y_classes_base[img_key]
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.title(f"Target: {med_img}\nPred: {pred_img}\nRattio: {round(pred_img/med_img, 2)}")
plt.show()

# %%
img_key = 5
resize_img = (200,200)
image_test = previsao_imagens + '/' + lista_cell[img_key]

y_classes_base = [n.split('rot')[1] for n in lista_cell]
y_classes_base = [int(n.split('_')[0]) for n in y_classes_base]

img = Image.open(image_test)
img = img.resize(resize_img)
img = np.asarray(img)[:,:,:3]
img_to_prd = np.expand_dims(img, axis=0)

pred_img = modelo.predict(img_to_prd)[0]
pred_img = round(float(pred_img), 2)
med_img = y_classes_base[img_key]
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.title(f"Target: {med_img}\nPred: {pred_img}\nRattio: {round(pred_img/med_img, 2)}")
plt.show()

# %%
img_key = 37
resize_img = (200,200)
image_test = previsao_imagens + '/' + lista_cell[img_key]

y_classes_base = [n.split('rot')[1] for n in lista_cell]
y_classes_base = [int(n.split('_')[0]) for n in y_classes_base]

img = Image.open(image_test)
img = img.resize(resize_img)
img = np.asarray(img)[:,:,:3]
img_to_prd = np.expand_dims(img, axis=0)

pred_img = modelo.predict(img_to_prd)[0]
pred_img = round(float(pred_img), 2)
med_img = y_classes_base[img_key]
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.title(f"Target: {med_img}\nPred: {pred_img}\nRattio: {round(pred_img/med_img, 2)}")
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c8daaa9d-6377-4e73-9571-1ae0cf7200fc' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
