# %% [markdown]
# <a href="https://colab.research.google.com/github/eloiza-dias/artigo_imagens_microsc/blob/main/4_Redes_neurais_3T3_menor_erro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linhagem 3T3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install util-gfsilveira
# Out:
# Collecting util-gfsilveira
#   Downloading util_gfsilveira-0.1-py3-none-any.whl (3.1 kB)
# Installing collected packages: util-gfsilveira
# Successfully installed util-gfsilveira-0.1

# %% [markdown]
# # Importações estruturação dos dados

# %%
#organização dos arquivos
import os
#salvar/carregar arquivos em diferentes formatos
import joblib
#organizando os arquivos de forma aleatória
import random
#gerar gráfico
import matplotlib
#estruturação dos dados
import numpy as np
#gerar gráfico
import seaborn as sns
#gerar gráfico
import matplotlib.pyplot as plt
#gerar imagem
import matplotlib.image as mpimg

# %% [markdown]
# # Importação do modelo de CNN

# %%
#modelo de revisão redes neurais - cnn
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
#from keras.utils import to_categorical
from util import meus_uteis, timeProcess, mask_corr_graphic, printLis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %% [markdown]
# Os documentos de diferentes arquivos serão armazenados nesse diretório

# %%
diretorio = '/content/drive/MyDrive/1_Informações_scripts' #alimentando a variável com os arquivos da pasta datasets
lista_dados = os.listdir(diretorio) #listando os arquivos dessa pasta
printLis(lista_dados) #printando as diferentes listas
# Out:
# -------------
# -=< Lista >=-
# -------------
# 0 -> lista_img_camp_clar_100_resized_regressao_3T3_samehuh72021-10-25.gz
# 1 -> lista_rotulo_camp_clar_100_resized_regressao_3T3_samehuh72021-10-25.gz
# 2 -> lista_img_camp_clar_100_resized_regressao_A549_samehuh72021-10-25.gz
# 3 -> lista_rotulo_camp_clar_100_resized_regressao_A549_samehuh72021-10-25.gz
# 4 -> lista_img_camp_clar_100_resized_regressao_huh7_samehuh72021-10-25.gz
# 5 -> lista_rotulo_camp_clar_100_resized_regressao_huh7_samehuh72021-10-25.gz
# 6 -> model_A549_samehuh7_img2021-10-26.h5
# 7 -> model_huh7_samehuh7_img2021-10-26.h5
# 8 -> model__3T3_samehuh7_img2021-10-26.h5
# 9 -> model_A549_samehuh7_img_40_602021-10-27.h5
# 10 -> model_huh7_samehuh7_img_40_602021-10-27.h5
# 11 -> model__3T3_samehuh7_img_40_602021-10-27.h5
# 12 -> lista_img_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 13 -> lista_rotulo_camp_clar_100_resized_regressao_A5492021-11-9.gz
# 14 -> lista_img_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 15 -> lista_rotulo_camp_clar_75_resized_regressao_A5492021-11-9.gz
# 16 -> lista_img_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 17 -> lista_rotulo_camp_clar_50_resized_regressao_A5492021-11-9.gz
# 18 -> lista_img_camp_clar_25_resized_regressao_A5492021-11-9.gz
# 19 -> lista_rotulo_camp_clar_25_resized_regressao_A5492021-11-9.gz
# 20 -> lista_img_camp_clar_100_resized_regressao_huh72021-11-9.gz
# 21 -> lista_rotulo_camp_clar_100_resized_regressao_huh72021-11-9.gz
# 22 -> lista_img_camp_clar_75_resized_regressao_HUH72021-11-9.gz
# 23 -> lista_rotulo_camp_clar_75_resized_regressao_HUH72021-11-9.gz
# 24 -> lista_img_camp_clar_50_resized_regressao_HUH72021-11-9.gz
# 25 -> lista_rotulo_camp_clar_50_resized_regressao_HUH72021-11-9.gz
# 26 -> lista_rotulo_camp_clar_25_resized_regressao_HUH72021-11-9.gz
# 27 -> lista_img_camp_clar_25_resized_regressao_HUH72021-11-9.gz
# 28 -> lista_img_camp_clar_100_resized_regressao_3T32021-11-9.gz
# 29 -> lista_rotulo_camp_clar_100_resized_regressao_3T32021-11-9.gz
# 30 -> lista_img_camp_clar_75_resized_regressao_3T3_2021-11-9.gz
# 31 -> lista_rotulo_camp_clar_75_resized_regressao_3T3_2021-11-9.gz
# 32 -> lista_img_camp_clar_50_resized_regressao_3T3_2021-11-9.gz
# 33 -> lista_rotulo_camp_clar_50_resized_regressao_3T3_2021-11-9.gz
# 34 -> lista_img_camp_clar_25_resized_regressao_3T3_2021-11-9.gz
# 35 -> lista_rotulo_camp_clar_25_resized_regressao_3T3_2021-11-9.gz
# 36 -> model_A549_100_75_50_25_2021-11-11.h5
# 37 -> model_HUH7_100_75_50_25_2021-11-11.h5
# 38 -> model_3T3_100_75_50_25_2021-11-11.h5
# 39 -> images_de_x_caracteristicas_a549.gz
# 40 -> images_de_y_caracteristicas_a549.gz
# 41 -> images_de_x_caracteristicas_Huh7.gz
# 42 -> rotulos_de_y_caracteristicas_Huh7.gz
# 43 -> images_de_x_caracteristicas_3T3.gz
# 44 -> rotulos_de_y_caracteristicas_3T3.gz
# 45 -> 1_images_de_X_train_a549_pior_modelo.gz
# 46 -> 1_images_de_y_train_a549_pior_modelo.gz
# 47 -> 2_images_de_X_test_a549_pior_modelo.gz
# 48 -> 2_images_de_y_test_a549_pior_modelo.gz
# 49 -> model__A549_regressao_maior_erro2022-1-26.h5
# 50 -> 1_images_de_X_train_a549_melhor_modelo2022-1-26.gz
# 51 -> 1_images_de_y_train_a549_melhor_modelo2022-1-26.gz
# 52 -> 2_images_de_X_test_a549_melhor_modelo2022-1-26.gz
# 53 -> 2_images_de_y_test_a549_melhor_modelo2022-1-26.gz
# 54 -> model__A549_regressao_menor_erro2022-1-26.h5
# 55 -> 3_images_de_X_train_huh7_pior_modelo.gz
# 56 -> 3_images_de_y_train_huh7_pior_modelo.gz
# 57 -> 4_images_de_X_test_huh7_pior_modelo.gz
# 58 -> 4_images_de_y_test_huh7_pior_modelo.gz
# 59 -> 3_images_de_X_train_huh7_melhor_modelo.gz
# 60 -> 3_images_de_y_train_huh7_melhor_modelo.gz
# 61 -> 4_images_de_X_test_huh7_melhor_modelo.gz
# 62 -> 4_images_de_y_test_huh7_melhor_modelo.gz
# 63 -> model__huh7_regressao_maior_erro2022-1-26.h5
# 64 -> model__huh7_regressao_menor_erro2022-1-26.h5

# %% [markdown]
# Para regressão, foi salvo 284 imagens a partir de 71 imagens originais

# %%
#lstando arquivos com as imagens 100%, 75%, 50%, 25%
for k, v in enumerate(lista_dados):
    if k in [28,30,32,34]:
        print(f'{k} -> {v}')
# Out:
# 28 -> lista_img_camp_clar_100_resized_regressao_3T32021-11-9.gz
# 30 -> lista_img_camp_clar_75_resized_regressao_3T3_2021-11-9.gz
# 32 -> lista_img_camp_clar_50_resized_regressao_3T3_2021-11-9.gz
# 34 -> lista_img_camp_clar_25_resized_regressao_3T3_2021-11-9.gz

# %%
# #lista- soma de 284 imagens
# imagem_camp_claro = joblib.load(diretorio + '/' + lista_dados[0]) #carregando o arquivo
# imagem_camp_claro.shape

# %% [markdown]
# ## x = características/imagens

# %%
#somando todas as imagens de diferentes tamanho
X_cem = joblib.load(diretorio+ '/' + lista_dados[28])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
X_setcin = joblib.load(diretorio+ '/' + lista_dados[30])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
X_cinq = joblib.load(diretorio+ '/' + lista_dados[32])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
X_vincin = joblib.load(diretorio+ '/' + lista_dados[34])

x = np.asarray(list(X_cem) + list(X_setcin) + list(X_cinq) + list(X_vincin))

x.shape
# Out:
# (832, 200, 200, 3)

# %%
# #somando cada lista gerada acima e salvando em um array
# x = np.asarray(imagem_camp_claro) #abriando em array as imagens
# x.shape #x - características (labels)

# %%
#joblib.dump(x, '/content/drive/MyDrive/1_Informações_scripts//images_de_x_caracteristicas_3T3.gz')
# Out:
# ['/content/drive/MyDrive/1_Informações_scripts//images_de_x_caracteristicas_3T3.gz']

# %% [markdown]
# Vamos definir nossos rótulos (y)

# %% [markdown]
# ## y = rótulos

# %% [markdown]
# Abrindo os rótulos que foram salvos na preparação das imagens

# %%
for k, v in enumerate(lista_dados):
    if k in [29,31,33,35]:
        print(f'{k} -> {v}')
# Out:
# 29 -> lista_rotulo_camp_clar_100_resized_regressao_3T32021-11-9.gz
# 31 -> lista_rotulo_camp_clar_75_resized_regressao_3T3_2021-11-9.gz
# 33 -> lista_rotulo_camp_clar_50_resized_regressao_3T3_2021-11-9.gz
# 35 -> lista_rotulo_camp_clar_25_resized_regressao_3T3_2021-11-9.gz

# %%
#somando todos os rótulos de diferentes tamanho
y_cem = joblib.load(diretorio+ '/' + lista_dados[29])

# 12 -> 00-lista_img_dapi_crop_75_resized_2021-5-12.gz
y_setcin = joblib.load(diretorio+ '/' + lista_dados[31])

# 10 -> 00-lista_img_dapi_crop_50_resized_2021-5-12.gz
y_cinq = joblib.load(diretorio+ '/' + lista_dados[33])

# 8 -> 00-lista_img_dapi_crop_25_resized_2021-5-12.gz
y_vincin = joblib.load(diretorio+ '/' + lista_dados[35])

y = np.asarray(list(y_cem) + list(y_setcin) + list(y_cinq) + list(y_vincin))

y.shape
# Out:
# (832,)

# %%
#joblib.dump(y, '/content/drive/MyDrive/1_Informações_scripts//rotulos_de_y_caracteristicas_3T3.gz')
# Out:
# ['/content/drive/MyDrive/1_Informações_scripts//rotulos_de_y_caracteristicas_3T3.gz']

# %%
# y_rotulo = joblib.load(diretorio + '/' + lista_dados[1]) #carregando os rotulos
# y = np.asarray(y_rotulo)
# y.shape

# %%
# y.max()
# y.min()

# %%
#Train and test split datasets for CNN model
#função que separa as imagens em teste e treino
from sklearn.model_selection import train_test_split

# %% [markdown]
# Separação de teste e treino a partir de uma biblioteca.

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
#variáveis recebem o número de imagens para tes e treino
print(f'{X_train.shape} \n{X_test.shape} \n{y_train.shape} \n{y_test.shape}')
# Out:
# (582, 200, 200, 3)
# (250, 200, 200, 3)
# (582,)
# (250,)

# %%
joblib.dump(X_train, '/content/drive/MyDrive/1_Informações_scripts//5_images_de_X_train_3T3_melhor_modelo.gz')
joblib.dump(y_train, '/content/drive/MyDrive/1_Informações_scripts//5_images_de_y_train_3T3_melhor_modelo.gz')
joblib.dump(X_test, '/content/drive/MyDrive/1_Informações_scripts//6_images_de_X_test_3T3_melhor_modelo.gz')
joblib.dump(y_test, '/content/drive/MyDrive/1_Informações_scripts//6_images_de_y_test_3T3_melhor_modelo.gz')
# Out:
# ['/content/drive/MyDrive/1_Informações_scripts//6_images_de_y_test_3T3_melhor_modelo.gz']

# %% [markdown]
# 198 - imagens treino/86 - imagens teste - - 198 rótulos para imagens de treino/86 rótulos para imagens de teste

# %% [markdown]
# Para treinar o modelo, geralmente é selecionada 30% das imagens para o treino e 70% para teste. Para isso, as imagens são guardadas em uma variável de teste (somente 30%) e o restante vai para o treino.

# %% [markdown]
# ### Determinação do modelo

# %%
modelo = Sequential()
modelo.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=X_train[0].shape))
#função de ativação relu é muito utilizado para problemas de regressão
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(64, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(128, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Conv2D(256, kernel_size=3, activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
modelo.add(Flatten())
modelo.add(Dropout(0.9))
modelo.add(Dense(1, activation='linear'))
#apenas uma saída e de forma linear
modelo.compile(optimizer='adam', loss='mse', metrics=['mean_absolute_error'])
print(modelo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dropout (Dropout)           (None, 25600)             0
#
#  dense (Dense)               (None, 1)                 25601
#
# =================================================================
# Total params: 414,017
# Trainable params: 414,017
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Após correr o modelo de Redes Neurais, vamos treina-lo em algumas rodadas e verificar a acurácia.

# %% [markdown]
# Guardando&nbsp;em&nbsp;uma&nbsp;variável&nbsp;o&nbsp;treinamento&nbsp;do&nbsp;modelo&nbsp;-&nbsp;informando&nbsp;as&nbsp;imagens&nbsp;com&nbsp;as&nbsp;caracteristicas (X_treino) e junto a elas os rótulos, validando com os valores de teste em 10 rodadas

# %%
#rodadas de treinamento
history = modelo.fit(
                        X_train,
                        y_train,
                        validation_data=(X_test, y_test),
                        epochs=50,
                        batch_size=12
                    )
# Out:
# Epoch 1/50
# 49/49 [==============================] - 55s 1s/step - loss: 35377.6719 - mean_absolute_error: 141.0776 - val_loss: 42984.2578 - val_mean_absolute_error: 140.6440
# Epoch 2/50
# 49/49 [==============================] - 55s 1s/step - loss: 32855.3125 - mean_absolute_error: 134.8123 - val_loss: 34073.7656 - val_mean_absolute_error: 150.4758
# Epoch 3/50
# 49/49 [==============================] - 53s 1s/step - loss: 32481.6602 - mean_absolute_error: 133.4172 - val_loss: 33760.5625 - val_mean_absolute_error: 147.2055
# Epoch 4/50
# 49/49 [==============================] - 53s 1s/step - loss: 34104.7500 - mean_absolute_error: 136.9541 - val_loss: 39668.1250 - val_mean_absolute_error: 138.1441
# Epoch 5/50
# 49/49 [==============================] - 53s 1s/step - loss: 33535.7305 - mean_absolute_error: 136.1358 - val_loss: 34789.6055 - val_mean_absolute_error: 139.3928
# Epoch 6/50
# 49/49 [==============================] - 53s 1s/step - loss: 31891.1680 - mean_absolute_error: 134.8833 - val_loss: 38163.3828 - val_mean_absolute_error: 137.6872
# Epoch 7/50
# 49/49 [==============================] - 53s 1s/step - loss: 34269.2148 - mean_absolute_error: 137.3288 - val_loss: 38398.3047 - val_mean_absolute_error: 137.6260
# Epoch 8/50
# 49/49 [==============================] - 52s 1s/step - loss: 31774.7734 - mean_absolute_error: 132.5031 - val_loss: 34175.1406 - val_mean_absolute_error: 141.7172
# Epoch 9/50
# 49/49 [==============================] - 52s 1s/step - loss: 33015.6055 - mean_absolute_error: 133.9207 - val_loss: 36148.7539 - val_mean_absolute_error: 137.4733
# Epoch 10/50
# 49/49 [==============================] - 52s 1s/step - loss: 30667.2891 - mean_absolute_error: 132.9911 - val_loss: 35319.8711 - val_mean_absolute_error: 137.9436
# Epoch 11/50
# 49/49 [==============================] - 52s 1s/step - loss: 30446.6738 - mean_absolute_error: 131.1915 - val_loss: 33669.0625 - val_mean_absolute_error: 145.4808
# Epoch 12/50
# 49/49 [==============================] - 52s 1s/step - loss: 30886.4785 - mean_absolute_error: 133.0709 - val_loss: 34167.2109 - val_mean_absolute_error: 139.7424
# Epoch 13/50
# 49/49 [==============================] - 52s 1s/step - loss: 32045.7051 - mean_absolute_error: 135.0527 - val_loss: 37867.3594 - val_mean_absolute_error: 137.2143
# Epoch 14/50
# 49/49 [==============================] - 52s 1s/step - loss: 31291.6074 - mean_absolute_error: 131.7767 - val_loss: 37301.6328 - val_mean_absolute_error: 139.4314
# Epoch 15/50
# 49/49 [==============================] - 52s 1s/step - loss: 31339.2500 - mean_absolute_error: 131.5137 - val_loss: 39438.2773 - val_mean_absolute_error: 137.6945
# Epoch 16/50
# 49/49 [==============================] - 53s 1s/step - loss: 31154.5527 - mean_absolute_error: 131.6290 - val_loss: 33450.2422 - val_mean_absolute_error: 143.5172
# Epoch 17/50
# 49/49 [==============================] - 52s 1s/step - loss: 31318.0781 - mean_absolute_error: 130.2258 - val_loss: 35819.2461 - val_mean_absolute_error: 135.3234
# Epoch 18/50
# 49/49 [==============================] - 52s 1s/step - loss: 30256.5059 - mean_absolute_error: 131.3150 - val_loss: 34035.9492 - val_mean_absolute_error: 136.6703
# Epoch 19/50
# 49/49 [==============================] - 52s 1s/step - loss: 30673.2930 - mean_absolute_error: 132.0655 - val_loss: 32808.8984 - val_mean_absolute_error: 144.2711
# Epoch 20/50
# 49/49 [==============================] - 52s 1s/step - loss: 46772.0859 - mean_absolute_error: 150.7430 - val_loss: 35836.5977 - val_mean_absolute_error: 138.1789
# Epoch 21/50
# 49/49 [==============================] - 52s 1s/step - loss: 32207.0996 - mean_absolute_error: 134.0129 - val_loss: 35162.0234 - val_mean_absolute_error: 138.8472
# Epoch 22/50
# 49/49 [==============================] - 52s 1s/step - loss: 31305.0371 - mean_absolute_error: 132.1050 - val_loss: 37489.3750 - val_mean_absolute_error: 137.6786
# Epoch 23/50
# 49/49 [==============================] - 52s 1s/step - loss: 30786.1855 - mean_absolute_error: 132.3136 - val_loss: 34990.5586 - val_mean_absolute_error: 139.2092
# Epoch 24/50
# 49/49 [==============================] - 52s 1s/step - loss: 31424.1992 - mean_absolute_error: 131.7047 - val_loss: 34746.5586 - val_mean_absolute_error: 139.8688
# Epoch 25/50
# 49/49 [==============================] - 52s 1s/step - loss: 30721.9863 - mean_absolute_error: 132.3477 - val_loss: 35406.8477 - val_mean_absolute_error: 138.4636
# Epoch 26/50
# 49/49 [==============================] - 52s 1s/step - loss: 30950.2480 - mean_absolute_error: 131.4020 - val_loss: 34300.3438 - val_mean_absolute_error: 141.4395
# Epoch 27/50
# 49/49 [==============================] - 52s 1s/step - loss: 31031.0723 - mean_absolute_error: 133.8517 - val_loss: 33938.7422 - val_mean_absolute_error: 143.7072
# Epoch 28/50
# 49/49 [==============================] - 52s 1s/step - loss: 30738.7246 - mean_absolute_error: 131.8656 - val_loss: 34544.3633 - val_mean_absolute_error: 140.4010
# Epoch 29/50
# 49/49 [==============================] - 52s 1s/step - loss: 30136.4082 - mean_absolute_error: 131.5780 - val_loss: 33852.1797 - val_mean_absolute_error: 144.8366
# Epoch 30/50
# 49/49 [==============================] - 52s 1s/step - loss: 31323.1367 - mean_absolute_error: 130.2805 - val_loss: 33901.6719 - val_mean_absolute_error: 143.8951
# Epoch 31/50
# 49/49 [==============================] - 53s 1s/step - loss: 31003.3535 - mean_absolute_error: 132.3111 - val_loss: 33896.7461 - val_mean_absolute_error: 143.8802
# Epoch 32/50
# 49/49 [==============================] - 56s 1s/step - loss: 30494.2129 - mean_absolute_error: 132.2633 - val_loss: 37550.0234 - val_mean_absolute_error: 137.5463
# Epoch 33/50
# 49/49 [==============================] - 53s 1s/step - loss: 31738.0039 - mean_absolute_error: 133.2722 - val_loss: 36382.7656 - val_mean_absolute_error: 137.6691
# Epoch 34/50
# 49/49 [==============================] - 52s 1s/step - loss: 31724.7070 - mean_absolute_error: 133.8090 - val_loss: 33832.6602 - val_mean_absolute_error: 144.4760
# Epoch 35/50
# 49/49 [==============================] - 52s 1s/step - loss: 31036.1953 - mean_absolute_error: 134.8433 - val_loss: 35619.1289 - val_mean_absolute_error: 138.0612
# Epoch 36/50
# 49/49 [==============================] - 52s 1s/step - loss: 30978.9004 - mean_absolute_error: 132.3310 - val_loss: 34552.6875 - val_mean_absolute_error: 154.1062
# Epoch 37/50
# 49/49 [==============================] - 52s 1s/step - loss: 30661.8633 - mean_absolute_error: 131.1303 - val_loss: 33781.2266 - val_mean_absolute_error: 145.1804
# Epoch 38/50
# 49/49 [==============================] - 52s 1s/step - loss: 30070.9043 - mean_absolute_error: 132.4691 - val_loss: 34198.5273 - val_mean_absolute_error: 151.6189
# Epoch 39/50
# 49/49 [==============================] - 52s 1s/step - loss: 30591.5938 - mean_absolute_error: 132.2490 - val_loss: 34319.7930 - val_mean_absolute_error: 140.8018
# Epoch 40/50
# 49/49 [==============================] - 52s 1s/step - loss: 30558.2129 - mean_absolute_error: 132.6717 - val_loss: 34737.8633 - val_mean_absolute_error: 139.3557
# Epoch 41/50
# 49/49 [==============================] - 52s 1s/step - loss: 31027.8223 - mean_absolute_error: 131.1272 - val_loss: 36572.9258 - val_mean_absolute_error: 137.4060
# Epoch 42/50
# 49/49 [==============================] - 52s 1s/step - loss: 30356.7637 - mean_absolute_error: 130.8839 - val_loss: 33813.0508 - val_mean_absolute_error: 147.9484
# Epoch 43/50
# 49/49 [==============================] - 52s 1s/step - loss: 30756.0586 - mean_absolute_error: 133.9114 - val_loss: 33977.4102 - val_mean_absolute_error: 142.2433
# Epoch 44/50
# 49/49 [==============================] - 52s 1s/step - loss: 30232.0449 - mean_absolute_error: 131.4405 - val_loss: 35753.6836 - val_mean_absolute_error: 137.7179
# Epoch 45/50
# 49/49 [==============================] - 52s 1s/step - loss: 30859.5332 - mean_absolute_error: 130.3058 - val_loss: 33761.1211 - val_mean_absolute_error: 147.4564
# Epoch 46/50
# 49/49 [==============================] - 52s 1s/step - loss: 30244.4160 - mean_absolute_error: 133.0311 - val_loss: 38004.4258 - val_mean_absolute_error: 137.3833
# Epoch 47/50
# 49/49 [==============================] - 52s 1s/step - loss: 30668.6211 - mean_absolute_error: 130.3758 - val_loss: 33795.0664 - val_mean_absolute_error: 143.3692
# Epoch 48/50
# 49/49 [==============================] - 52s 1s/step - loss: 30455.7793 - mean_absolute_error: 131.4203 - val_loss: 34276.5781 - val_mean_absolute_error: 140.4591
# Epoch 49/50
# 49/49 [==============================] - 52s 1s/step - loss: 30186.6934 - mean_absolute_error: 131.8938 - val_loss: 34632.6289 - val_mean_absolute_error: 139.2156
# Epoch 50/50
# 49/49 [==============================] - 52s 1s/step - loss: 30767.4883 - mean_absolute_error: 131.7829 - val_loss: 36157.7617 - val_mean_absolute_error: 137.3208

# %%
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/1_Informações_scripts//model__3T3_regressao_menor_erro'+data+'.h5')

# %% [markdown]
# ## Avaliação da Acurácia

# %% [markdown]
# Existem algumas maneiras de se avaliar a acurácia dos algoritmos, para algoritmo de regressão, as métricas mais comuns são Erro médio absoluto (MSE) não se baseia na média a partir de valores discrepantes. Erro Médio quadrático (MAE) considera os valores discrepantes entre as variáveis, apontando maior erro.

# %% [markdown]
# O algoritmo avalia o valor previsto e subtraí pelo valor conhecido, depois é calculado a média entre cada valor.

# %%
# #salvando o modelo
# data = timeProcess()[1]
# modelo.save('arquivos_text_modelo_imagens//model_camp_claro_A549_regressao'+data+'.h5')

# %%
#gráfico avaliando a acurácia a partir de treino e teste
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Acurácia do modelo - MAE')
plt.ylabel('acurácia')
plt.xlabel('rodadas')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#avaliando a previsão do modelo com os rótulos
prev = modelo.predict(X_test)
plt.title('Previsão dos valores Operetta')
plt.ylabel('Rótulos')
plt.xlabel('Previsão')
plt.plot(prev)#azul - o que o modelo previu
plt.plot(y_test)#laranja - o que se sabe - observado
plt.show()

# %%
# Qualit model analisys
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error

# %%
#buscando pelas métricas
print(f"{round(r2_score(y_test, prev) * 100, 2)}%") #raíz quadrada
print(f"{round(mean_absolute_error(y_test, prev), 2)}") 
print(f"{round(mean_squared_log_error(y_test, prev), 2)}") #erro médio quadrático
# print(f"{round(median_absolute_error(y_test, prev), 2)}")#Erro médio absoluto sem %
# Out:
# -3.83%
# 139.74
# 1.04

# %%
mean_absolute_error(y_test, prev)
# Out:
# 139.74087579345704

# %%
print(f"{round(mean_absolute_error(y_test, prev) * 100, 2)}%")
# Out:
# 13974.09%

# %%
print(f"{round(mean_squared_log_error(y_test, prev) * 100, 2)}%")
# Out:
# 104.28%

# %%
# #salvando o modelo
data = timeProcess()[1]
modelo.save('/content/drive/MyDrive/1_Informações_scripts//model_3T3_100_75_50_25_'+data+'.h5')

# %% [markdown]
# ## Predição Regressão

# %%
from PIL import Image

# %%
#chamando o diretório com as imagens
previsao_imagens = "/content/drive/MyDrive/imagens_3T3/Imagens_3T3_27_07_2021_Projeto_Ari_Ale"
lista_cell = os.listdir(previsao_imagens)
#lista_cell #lista das imagens

# %%
lista_cell
# Out:
# ['Imagens_3T3_27_07_2021_Ari_Alessandra_LABCET_2019',
#  'Imagens_3T3_27_07_2021_Projeto_Ari_Ale']

# %%
img_key = 20
resize_img = (200,200)
image_test = previsao_imagens + '/' + lista_cell[img_key]

y_classes_base = [n.split('rot')[1] for n in lista_cell] #cortando o nome da image
y_classes_base = [int(n.split('_')[0]) for n in y_classes_base]

#trabalhando com as dimensões e mudando para numpy
img = Image.open(image_test)
img = img.resize(resize_img)
img = np.asarray(img)[:,:,:3]
img_to_prd = np.expand_dims(img, axis=0)


#gerando o gráfico
pred_img = modelo.predict(img_to_prd)[0]
pred_img = round(float(pred_img), 2)
med_img = y_classes_base[img_key]
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.title(f"Target: {med_img}\nPred: {pred_img}\nRattio: {round(pred_img/med_img, 2)}")
plt.show()

# %%
img_key = 5
resize_img = (200,200)
image_test = previsao_imagens + '/' + lista_cell[img_key]

y_classes_base = [n.split('rot')[1] for n in lista_cell]
y_classes_base = [int(n.split('_')[0]) for n in y_classes_base]

img = Image.open(image_test)
img = img.resize(resize_img)
img = np.asarray(img)[:,:,:3]
img_to_prd = np.expand_dims(img, axis=0)

pred_img = modelo.predict(img_to_prd)[0]
pred_img = round(float(pred_img), 2)
med_img = y_classes_base[img_key]
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.title(f"Target: {med_img}\nPred: {pred_img}\nRattio: {round(pred_img/med_img, 2)}")
plt.show()

# %%
img_key = 15
resize_img = (200,200)
image_test = previsao_imagens + '/' + lista_cell[img_key]

y_classes_base = [n.split('rot')[1] for n in lista_cell]
y_classes_base = [int(n.split('_')[0]) for n in y_classes_base]

img = Image.open(image_test)
img = img.resize(resize_img)
img = np.asarray(img)[:,:,:3]
img_to_prd = np.expand_dims(img, axis=0)

pred_img = modelo.predict(img_to_prd)[0]
pred_img = round(float(pred_img), 2)
med_img = y_classes_base[img_key]
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.title(f"Target: {med_img}\nPred: {pred_img}\nRattio: {round(pred_img/med_img, 2)}")
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c8daaa9d-6377-4e73-9571-1ae0cf7200fc' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
